# %% [markdown]
# # Step 1: change kernel to match some other sheet (so CVT happen in correct session)

# %% [markdown]
# <br><br><br>
# ## <u>Dim_App</u>
# ### ToDo:
# - change Dim_App sql to bucket rogue characters into 'garbled' (or some such) bucket

# %%
CREATE MULTISET VOLATILE TABLE "dim_app.csv"
("SiteID"                      VARCHAR(107)  CHARACTER SET UNICODE 
,"Pattern_Type"                VARCHAR(105)  CHARACTER SET UNICODE 
,"Pattern"                     VARCHAR(131)  CHARACTER SET UNICODE 
,"App_Bucket"                  VARCHAR(129)  CHARACTER SET UNICODE 
,"Use_Bucket"                  VARCHAR(111)  CHARACTER SET UNICODE 
,"Priority"                    VARCHAR(107)  CHARACTER SET UNICODE 
) NO PRIMARY INDEX
ON COMMIT PRESERVE ROWS;
# Out:
# Success: 0 rows affected

# %%
INSERT INTO "dim_app.csv"
SELECT
  cast('Default' as varchar(107))
 ,cast('Equal' as varchar(105))
 ,cast('ATANASUITE' as varchar(131))
 ,cast('Atanasuite' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('1000' as varchar(107))
from (sel 1 one) i0    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('WIREPORTSERVER%' as varchar(131))
 ,cast('BOBJ' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('1010' as varchar(107))
from (sel 1 one) i1    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('BUSOBJ%' as varchar(131))
 ,cast('BOBJ' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('1011' as varchar(107))
from (sel 1 one) i2    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('WEBIRICHCLIENT%' as varchar(131))
 ,cast('BOBJ' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('1012' as varchar(107))
from (sel 1 one) i3    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Equal' as varchar(105))
 ,cast('BTEQ' as varchar(131))
 ,cast('BTEQ' as varchar(129))
 ,cast('ETL' as varchar(111))
 ,cast('1020' as varchar(107))
from (sel 1 one) i4    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Equal' as varchar(105))
 ,cast('HTTPD' as varchar(131))
 ,cast('HTTPD' as varchar(129))
 ,cast('Application' as varchar(111))
 ,cast('1030' as varchar(107))
from (sel 1 one) i5    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Equal' as varchar(105))
 ,cast('JMP' as varchar(131))
 ,cast('JMP' as varchar(129))
 ,cast('Application' as varchar(111))
 ,cast('1040' as varchar(107))
from (sel 1 one) i6    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Equal' as varchar(105))
 ,cast('DTSRUN' as varchar(131))
 ,cast('MS SSIS' as varchar(129))
 ,cast('ETL' as varchar(111))
 ,cast('1050' as varchar(107))
from (sel 1 one) i7    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Equal' as varchar(105))
 ,cast('PHP' as varchar(131))
 ,cast('PHP' as varchar(129))
 ,cast('Application' as varchar(111))
 ,cast('1070' as varchar(107))
from (sel 1 one) i8    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Equal' as varchar(105))
 ,cast('RSESSION' as varchar(131))
 ,cast('R' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('1080' as varchar(107))
from (sel 1 one) i9    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Equal' as varchar(105))
 ,cast('SAS' as varchar(131))
 ,cast('SAS' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('1090' as varchar(107))
from (sel 1 one) i10    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Equal' as varchar(105))
 ,cast('Queryman' as varchar(131))
 ,cast('SQLAssistant' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('1100' as varchar(107))
from (sel 1 one) i11    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Equal' as varchar(105))
 ,cast('SQLA' as varchar(131))
 ,cast('SQLAssistant' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('1110' as varchar(107))
from (sel 1 one) i12    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('BRIO%' as varchar(131))
 ,cast('BRIO Query' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('1111' as varchar(107))
from (sel 1 one) i13    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Equal' as varchar(105))
 ,cast('ARCMain' as varchar(131))
 ,cast('TTU' as varchar(129))
 ,cast('Backup' as varchar(111))
 ,cast('1120' as varchar(107))
from (sel 1 one) i14    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Equal' as varchar(105))
 ,cast('DSMain' as varchar(131))
 ,cast('TTU' as varchar(129))
 ,cast('Backup' as varchar(111))
 ,cast('1130' as varchar(107))
from (sel 1 one) i15    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Equal' as varchar(105))
 ,cast('MULTILOAD' as varchar(131))
 ,cast('TTU' as varchar(129))
 ,cast('ETL' as varchar(111))
 ,cast('1140' as varchar(107))
from (sel 1 one) i16    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Equal' as varchar(105))
 ,cast('TPTSTRM' as varchar(131))
 ,cast('TTU' as varchar(129))
 ,cast('Stream' as varchar(111))
 ,cast('1170' as varchar(107))
from (sel 1 one) i17    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Equal' as varchar(105))
 ,cast('TPUMPEXE' as varchar(131))
 ,cast('TTU' as varchar(129))
 ,cast('Stream' as varchar(111))
 ,cast('1190' as varchar(107))
from (sel 1 one) i18    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Equal' as varchar(105))
 ,cast('TERADATAKERNEL' as varchar(131))
 ,cast('Jupyter' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('1234' as varchar(107))
from (sel 1 one) i19    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Equal' as varchar(105))
 ,cast('OUTLOOK' as varchar(131))
 ,cast('MS Office' as varchar(129))
 ,cast('Application' as varchar(111))
 ,cast('1500' as varchar(107))
from (sel 1 one) i20    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('AGINITY.NETEZZAWORKBENCH%' as varchar(131))
 ,cast('Netezza' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('10000' as varchar(107))
from (sel 1 one) i21    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('SPOTFIRE%' as varchar(131))
 ,cast('Spotfire' as varchar(129))
 ,cast('Application' as varchar(111))
 ,cast('10010' as varchar(107))
from (sel 1 one) i22    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('ADEPTRA_SELFSERVREPORT%' as varchar(131))
 ,cast('Adeptra' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('10100' as varchar(107))
from (sel 1 one) i23    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('BIBUSTKSERVERMAIN%' as varchar(131))
 ,cast('Cognos' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('10200' as varchar(107))
from (sel 1 one) i24    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('M_DB.TER.GCC4P64%' as varchar(131))
 ,cast('Ab Initio' as varchar(129))
 ,cast('ETL' as varchar(111))
 ,cast('10300' as varchar(107))
from (sel 1 one) i25    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('LOADIPSHARETABLE%' as varchar(131))
 ,cast('Unknown' as varchar(129))
 ,cast('Unknown' as varchar(111))
 ,cast('10400' as varchar(107))
from (sel 1 one) i26    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('AGINIT~1:NET:SS%' as varchar(131))
 ,cast('Netezza' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('10500' as varchar(107))
from (sel 1 one) i27    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('ISSERVEREXEC%' as varchar(131))
 ,cast('MS SSIS' as varchar(129))
 ,cast('ETL' as varchar(111))
 ,cast('10600' as varchar(107))
from (sel 1 one) i28    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('ISSERVEREXEC%' as varchar(131))
 ,cast('SSIS' as varchar(129))
 ,cast('ETL' as varchar(111))
 ,cast('10700' as varchar(107))
from (sel 1 one) i29    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('NODEDBQUERY%' as varchar(131))
 ,cast('LavaStorm' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('10800' as varchar(107))
from (sel 1 one) i30    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('QVCONNECT32%' as varchar(131))
 ,cast('QlikView' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('10900' as varchar(107))
from (sel 1 one) i31    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('QVCONNECT64%' as varchar(131))
 ,cast('QlikView' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('11000' as varchar(107))
from (sel 1 one) i32    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('AL_DESIGNER%' as varchar(131))
 ,cast('SAP BODS' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('11100' as varchar(107))
from (sel 1 one) i33    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('TABPROTO%' as varchar(131))
 ,cast('Tableau' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('11200' as varchar(107))
from (sel 1 one) i34    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('NODEDBEXEC%' as varchar(131))
 ,cast('LavaStorm' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('11300' as varchar(107))
from (sel 1 one) i35    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('DTS%' as varchar(131))
 ,cast('MS SSIS' as varchar(129))
 ,cast('ETL' as varchar(111))
 ,cast('11400' as varchar(107))
from (sel 1 one) i36    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('DTE%' as varchar(131))
 ,cast('MS SSIS' as varchar(129))
 ,cast('ETL' as varchar(111))
 ,cast('11401' as varchar(107))
from (sel 1 one) i37    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('AL_ENGINE%' as varchar(131))
 ,cast('SAP BODS' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('11500' as varchar(107))
from (sel 1 one) i38    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('TBUILDEXE%' as varchar(131))
 ,cast('TTU' as varchar(129))
 ,cast('ETL' as varchar(111))
 ,cast('11501' as varchar(107))
from (sel 1 one) i39    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('ISSERVICE%' as varchar(131))
 ,cast('Teradata' as varchar(129))
 ,cast('ETL' as varchar(111))
 ,cast('11600' as varchar(107))
from (sel 1 one) i40    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('TDLOADEXE%' as varchar(131))
 ,cast('TTU' as varchar(129))
 ,cast('ETL' as varchar(111))
 ,cast('11601' as varchar(107))
from (sel 1 one) i41    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('M8MULPRC%' as varchar(131))
 ,cast('Microstrategy' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('11700' as varchar(107))
from (sel 1 one) i42    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('QUERYMAN%' as varchar(131))
 ,cast('SQLAssistant' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('11800' as varchar(107))
from (sel 1 one) i43    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('TPTUPD%' as varchar(131))
 ,cast('TTU' as varchar(129))
 ,cast('ETL' as varchar(111))
 ,cast('11801' as varchar(107))
from (sel 1 one) i44    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('SQLA:NET%' as varchar(131))
 ,cast('SQLAssistant' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('11900' as varchar(107))
from (sel 1 one) i45    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('EXECUTOR%' as varchar(131))
 ,cast('TTU' as varchar(129))
 ,cast('ETL' as varchar(111))
 ,cast('12000' as varchar(107))
from (sel 1 one) i46    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('FASTLOAD%' as varchar(131))
 ,cast('TTU' as varchar(129))
 ,cast('ETL' as varchar(111))
 ,cast('12100' as varchar(107))
from (sel 1 one) i47    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('MULTLOAD%' as varchar(131))
 ,cast('TTU' as varchar(129))
 ,cast('ETL' as varchar(111))
 ,cast('12200' as varchar(107))
from (sel 1 one) i48    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('RUNDLL32%' as varchar(131))
 ,cast('Unknown' as varchar(129))
 ,cast('Unknown' as varchar(111))
 ,cast('12300' as varchar(107))
from (sel 1 one) i49    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('ALTERYX%' as varchar(131))
 ,cast('Alteryx' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('12400' as varchar(107))
from (sel 1 one) i50    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('TRANSDA%' as varchar(131))
 ,cast('Cognos' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('12500' as varchar(107))
from (sel 1 one) i51    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('MSQRY32%' as varchar(131))
 ,cast('MS Office' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('12600' as varchar(107))
from (sel 1 one) i52    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('TDWMDIP%' as varchar(131))
 ,cast('Teradata' as varchar(129))
 ,cast('Internal' as varchar(111))
 ,cast('12700' as varchar(107))
from (sel 1 one) i53    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('FASTEXP%' as varchar(131))
 ,cast('TTU' as varchar(129))
 ,cast('Export' as varchar(111))
 ,cast('12800' as varchar(107))
from (sel 1 one) i54    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('OLELOAD%' as varchar(131))
 ,cast('TTU' as varchar(129))
 ,cast('ETL' as varchar(111))
 ,cast('12900' as varchar(107))
from (sel 1 one) i55    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('TPTLOAD%' as varchar(131))
 ,cast('TTU' as varchar(129))
 ,cast('ETL' as varchar(111))
 ,cast('13000' as varchar(107))
from (sel 1 one) i56    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('DTEXEC%' as varchar(131))
 ,cast('MS SSIS' as varchar(129))
 ,cast('ETL' as varchar(111))
 ,cast('13200' as varchar(107))
from (sel 1 one) i57    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('SQLSERVR%' as varchar(131))
 ,cast('MS SQL Server' as varchar(129))
 ,cast('ETL' as varchar(111))
 ,cast('13211' as varchar(107))
from (sel 1 one) i58    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('MSMDSRV%' as varchar(131))
 ,cast('MS SSAS' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('13212' as varchar(107))
from (sel 1 one) i59    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('SSMS%' as varchar(131))
 ,cast('MS SQL Server' as varchar(129))
 ,cast('ETL' as varchar(111))
 ,cast('13213' as varchar(107))
from (sel 1 one) i60    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('DEVENV%' as varchar(131))
 ,cast('MS VisualStudio' as varchar(129))
 ,cast('Application' as varchar(111))
 ,cast('13300' as varchar(107))
from (sel 1 one) i61    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('IISEX%' as varchar(131))
 ,cast('MS VisualStudio' as varchar(129))
 ,cast('Application' as varchar(111))
 ,cast('13301' as varchar(107))
from (sel 1 one) i62    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('NVTERA%' as varchar(131))
 ,cast('NetVault' as varchar(129))
 ,cast('Backup' as varchar(111))
 ,cast('13400' as varchar(107))
from (sel 1 one) i63    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('ODBC%' as varchar(131))
 ,cast('ODBC' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('13401' as varchar(107))
from (sel 1 one) i64    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('ESSSVR%' as varchar(131))
 ,cast('Oracle Hyperion Essbase' as varchar(129))
 ,cast('Application' as varchar(111))
 ,cast('13402' as varchar(107))
from (sel 1 one) i65    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('OLAPISVR%' as varchar(131))
 ,cast('Oracle Hyperion Essbase' as varchar(129))
 ,cast('Application' as varchar(111))
 ,cast('13403' as varchar(107))
from (sel 1 one) i66    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('TPTEXP%' as varchar(131))
 ,cast('TTU' as varchar(129))
 ,cast('Export' as varchar(111))
 ,cast('13500' as varchar(107))
from (sel 1 one) i67    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('VECOMP%' as varchar(131))
 ,cast('TTU' as varchar(129))
 ,cast('ETL' as varchar(111))
 ,cast('13600' as varchar(107))
from (sel 1 one) i68    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('WINDDI%' as varchar(131))
 ,cast('TTU' as varchar(129))
 ,cast('ETL' as varchar(111))
 ,cast('13700' as varchar(107))
from (sel 1 one) i69    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('%INFORMATICA%' as varchar(131))
 ,cast('Informatica' as varchar(129))
 ,cast('ETL' as varchar(111))
 ,cast('13800' as varchar(107))
from (sel 1 one) i70    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('PMDTM' as varchar(131))
 ,cast('Informatica' as varchar(129))
 ,cast('ETL' as varchar(111))
 ,cast('13900' as varchar(107))
from (sel 1 one) i71    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('PMDESIGN' as varchar(131))
 ,cast('Informatica' as varchar(129))
 ,cast('ETL' as varchar(111))
 ,cast('14000' as varchar(107))
from (sel 1 one) i72    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('PMDTMSVC%' as varchar(131))
 ,cast('Informatica' as varchar(129))
 ,cast('ETL' as varchar(111))
 ,cast('14010' as varchar(107))
from (sel 1 one) i73    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('MICROSOFT.MASH%' as varchar(131))
 ,cast('MS PowerBI' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('14021' as varchar(107))
from (sel 1 one) i74    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('BIBUS%' as varchar(131))
 ,cast('Cognos' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('14100' as varchar(107))
from (sel 1 one) i75    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('COGTR%' as varchar(131))
 ,cast('Cognos' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('14200' as varchar(107))
from (sel 1 one) i76    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('TM1SD%' as varchar(131))
 ,cast('Cognos' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('14300' as varchar(107))
from (sel 1 one) i77    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('CRW32%' as varchar(131))
 ,cast('Crystal Reports' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('14400' as varchar(107))
from (sel 1 one) i78    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('DBVIS%' as varchar(131))
 ,cast('DbVisualizer' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('14500' as varchar(107))
from (sel 1 one) i79    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('UWSGI%' as varchar(131))
 ,cast('Teradata' as varchar(129))
 ,cast('Unknown' as varchar(111))
 ,cast('14600' as varchar(107))
from (sel 1 one) i80    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('TIWIZ%' as varchar(131))
 ,cast('TTU' as varchar(129))
 ,cast('ETL' as varchar(111))
 ,cast('14700' as varchar(107))
from (sel 1 one) i81    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('UNICA%' as varchar(131))
 ,cast('Unica' as varchar(129))
 ,cast('Application' as varchar(111))
 ,cast('14800' as varchar(107))
from (sel 1 one) i82    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('JDBC%' as varchar(131))
 ,cast('JDBC' as varchar(129))
 ,cast('Application' as varchar(111))
 ,cast('14900' as varchar(107))
from (sel 1 one) i83    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('JAVA%' as varchar(131))
 ,cast('JDBC' as varchar(129))
 ,cast('Application' as varchar(111))
 ,cast('14901' as varchar(107))
from (sel 1 one) i84    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('%/JMP' as varchar(131))
 ,cast('JMP' as varchar(129))
 ,cast('Application' as varchar(111))
 ,cast('15000' as varchar(107))
from (sel 1 one) i85    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('%PERL%' as varchar(131))
 ,cast('Perl' as varchar(129))
 ,cast('Application' as varchar(111))
 ,cast('15001' as varchar(107))
from (sel 1 one) i86    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('MSACCESS%' as varchar(131))
 ,cast('MS Office' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('15002' as varchar(107))
from (sel 1 one) i87    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('EXCEL%' as varchar(131))
 ,cast('MS Office' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('15003' as varchar(107))
from (sel 1 one) i88    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('POWERPNT%' as varchar(131))
 ,cast('MS Office' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('15004' as varchar(107))
from (sel 1 one) i89    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('QUERYCHAMELEON%' as varchar(131))
 ,cast('Nexus' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('15005' as varchar(107))
from (sel 1 one) i90    UNION ALL
SELECT
  cast('DEfault' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('TOAD%' as varchar(131))
 ,cast('Toad' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('15010' as varchar(107))
from (sel 1 one) i91    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('W3WP%' as varchar(131))
 ,cast('MS IIS' as varchar(129))
 ,cast('Application' as varchar(111))
 ,cast('15100' as varchar(107))
from (sel 1 one) i92    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('DOTNET%' as varchar(131))
 ,cast('MS .Net Driver' as varchar(129))
 ,cast('Application' as varchar(111))
 ,cast('15110' as varchar(107))
from (sel 1 one) i93    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('%ANACONDA%' as varchar(131))
 ,cast('Python' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('15200' as varchar(107))
from (sel 1 one) i94    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('%SASFound%' as varchar(131))
 ,cast('SAS' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('15300' as varchar(107))
from (sel 1 one) i95    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('QUICKFLOW%' as varchar(131))
 ,cast('SFDC' as varchar(129))
 ,cast('Application' as varchar(111))
 ,cast('15301' as varchar(107))
from (sel 1 one) i96    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('TSET%' as varchar(131))
 ,cast('TTU' as varchar(129))
 ,cast('Support' as varchar(111))
 ,cast('15400' as varchar(107))
from (sel 1 one) i97    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('%POWERBI%' as varchar(131))
 ,cast('PowerBI' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('15500' as varchar(107))
from (sel 1 one) i98    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('%TABLEAU%' as varchar(131))
 ,cast('Tableau' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('15600' as varchar(107))
from (sel 1 one) i99    ;

INSERT INTO "dim_app.csv"
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('BMT%' as varchar(131))
 ,cast('Cognos' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('15700' as varchar(107))
from (sel 1 one) i100    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('%PYT' as varchar(131))
 ,cast('Python' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('15800' as varchar(107))
from (sel 1 one) i101    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('%PYTHON%' as varchar(131))
 ,cast('Python' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('15900' as varchar(107))
from (sel 1 one) i102    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('DUL%' as varchar(131))
 ,cast('Teradata' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('16000' as varchar(107))
from (sel 1 one) i103    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('RAYTHEON%' as varchar(131))
 ,cast('Raytheon Inspect Analytics' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('16000' as varchar(107))
from (sel 1 one) i104    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Equal' as varchar(105))
 ,cast('1' as varchar(131))
 ,cast('Unknown' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('20000' as varchar(107))
from (sel 1 one) i105    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Equal' as varchar(105))
 ,cast('(DELETED)                     ' as varchar(131))
 ,cast('Unknown' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('20001' as varchar(107))
from (sel 1 one) i106    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Equal' as varchar(105))
 ,cast('?' as varchar(131))
 ,cast('Unknown' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('20002' as varchar(107))
from (sel 1 one) i107    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Equal' as varchar(105))
 ,cast('ACLDA64                       ' as varchar(131))
 ,cast('ACL for Win (Highbond)' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('20003' as varchar(107))
from (sel 1 one) i108    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('AQTV%             ' as varchar(131))
 ,cast('Advanced Query Tool' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('20004' as varchar(107))
from (sel 1 one) i109    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Equal' as varchar(105))
 ,cast('CAS                           ' as varchar(131))
 ,cast('Unknown' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('20005' as varchar(107))
from (sel 1 one) i110    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Equal' as varchar(105))
 ,cast('CMO_PANEL:NET:SS:16.20.09.000 ' as varchar(131))
 ,cast('Unknown' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('20006' as varchar(107))
from (sel 1 one) i111    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Equal' as varchar(105))
 ,cast('COLLECTION                    ' as varchar(131))
 ,cast('TD PDCR Procerss' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('20007' as varchar(107))
from (sel 1 one) i112    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Equal' as varchar(105))
 ,cast('COMPSRV                       ' as varchar(131))
 ,cast('SAS' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('20008' as varchar(107))
from (sel 1 one) i113    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Equal' as varchar(105))
 ,cast('CSPPEEK                       ' as varchar(131))
 ,cast('Crashdumps' as varchar(129))
 ,cast('System' as varchar(111))
 ,cast('20009' as varchar(107))
from (sel 1 one) i114    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Equal' as varchar(105))
 ,cast('D_UGAP_DATA.PY                ' as varchar(131))
 ,cast('Python' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('20010' as varchar(107))
from (sel 1 one) i115    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Equal' as varchar(105))
 ,cast('DBEAVER                       ' as varchar(131))
 ,cast('Universal DB Tool' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('20011' as varchar(107))
from (sel 1 one) i116    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Equal' as varchar(105))
 ,cast('DSAPI_SLAVE                   ' as varchar(131))
 ,cast('DataStage' as varchar(129))
 ,cast('ETL' as varchar(111))
 ,cast('20012' as varchar(107))
from (sel 1 one) i117    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Equal' as varchar(105))
 ,cast('HPMQUERYSERVICEQUEUE:NET:SS:13' as varchar(131))
 ,cast('Unknown' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('20013' as varchar(107))
from (sel 1 one) i118    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Equal' as varchar(105))
 ,cast('IMPADMIN                      ' as varchar(131))
 ,cast('Impromptu' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('20014' as varchar(107))
from (sel 1 one) i119    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Equal' as varchar(105))
 ,cast('INFORMATIONDESIGNTOOL         ' as varchar(131))
 ,cast('Business Objects' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('20015' as varchar(107))
from (sel 1 one) i120    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Equal' as varchar(105))
 ,cast('IR_ACO_DATALOADER%' as varchar(131))
 ,cast('Demand Tools - CRM' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('20016' as varchar(107))
from (sel 1 one) i121    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('KERNEL%' as varchar(131))
 ,cast('Azure Data Studio' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('20017' as varchar(107))
from (sel 1 one) i122    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('MSREPORTBUILDER%' as varchar(131))
 ,cast('SQL Server Reporting Services' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('20018' as varchar(107))
from (sel 1 one) i123    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('MULTITHREADSGENQUEUE%' as varchar(131))
 ,cast('Python' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('20019' as varchar(107))
from (sel 1 one) i124    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Equal' as varchar(105))
 ,cast('MYSQLD                        ' as varchar(131))
 ,cast('MySQL' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('20020' as varchar(107))
from (sel 1 one) i125    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Equal' as varchar(105))
 ,cast('ORCHDBUTIL                    ' as varchar(131))
 ,cast('DataStage' as varchar(129))
 ,cast('ETL' as varchar(111))
 ,cast('20021' as varchar(107))
from (sel 1 one) i126    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Equal' as varchar(105))
 ,cast('PHANTOM                       ' as varchar(131))
 ,cast('CRM' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('20022' as varchar(107))
from (sel 1 one) i127    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Equal' as varchar(105))
 ,cast('PMDTM                         ' as varchar(131))
 ,cast('Informatica' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('20023' as varchar(107))
from (sel 1 one) i128    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('PREVIEWPROCESSINGSERVICE%      ' as varchar(131))
 ,cast('SQL Server Reporting Services' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('20024' as varchar(107))
from (sel 1 one) i129    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Equal' as varchar(105))
 ,cast('R                             ' as varchar(131))
 ,cast('R Studio' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('20025' as varchar(107))
from (sel 1 one) i130    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('REPORTINGSERVICESSERVICE%' as varchar(131))
 ,cast('SQL Server Reporting Services' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('20026' as varchar(107))
from (sel 1 one) i131    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Equal' as varchar(105))
 ,cast('RTERM                         ' as varchar(131))
 ,cast('R Studio' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('20027' as varchar(107))
from (sel 1 one) i132    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Equal' as varchar(105))
 ,cast('RUNAGENT                      ' as varchar(131))
 ,cast('BMC(?)' as varchar(129))
 ,cast('System' as varchar(111))
 ,cast('20028' as varchar(107))
from (sel 1 one) i133    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Equal' as varchar(105))
 ,cast('RUNDLL32                      ' as varchar(131))
 ,cast('Windows App' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('20029' as varchar(107))
from (sel 1 one) i134    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Equal' as varchar(105))
 ,cast('SEGUIDE                       ' as varchar(131))
 ,cast('SAS' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('20030' as varchar(107))
from (sel 1 one) i135    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Equal' as varchar(105))
 ,cast('SQLDBX                        ' as varchar(131))
 ,cast('SQLDB Explorer' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('20031' as varchar(107))
from (sel 1 one) i136    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Equal' as varchar(105))
 ,cast('SRCLIB_DLL_X64-32             ' as varchar(131))
 ,cast('Alteryx' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('20032' as varchar(107))
from (sel 1 one) i137    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Equal' as varchar(105))
 ,cast('TDXODBC                       ' as varchar(131))
 ,cast('TD Linux ODBC' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('20033' as varchar(107))
from (sel 1 one) i138    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('TITAN2_%' as varchar(131))
 ,cast('unknown' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('20034' as varchar(107))
from (sel 1 one) i139    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Equal' as varchar(105))
 ,cast('TRNSFRMR                      ' as varchar(131))
 ,cast('Cognos' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('20035' as varchar(107))
from (sel 1 one) i140    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Equal' as varchar(105))
 ,cast('Unavailable                   ' as varchar(131))
 ,cast('unknown' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('20036' as varchar(107))
from (sel 1 one) i141    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Equal' as varchar(105))
 ,cast('UVSH                          ' as varchar(131))
 ,cast('DataStage' as varchar(129))
 ,cast('ETL' as varchar(111))
 ,cast('20037' as varchar(107))
from (sel 1 one) i142    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Equal' as varchar(105))
 ,cast('WRITE_UGAP_                   ' as varchar(131))
 ,cast('Apache Airflow' as varchar(129))
 ,cast('Analytic' as varchar(111))
 ,cast('20038' as varchar(107))
from (sel 1 one) i143    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('JOBRUNNER%' as varchar(131))
 ,cast('D3' as varchar(129))
 ,cast('ETL' as varchar(111))
 ,cast('144101' as varchar(107))
from (sel 1 one) i144    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('%PL%' as varchar(131))
 ,cast('Perl' as varchar(129))
 ,cast('Application' as varchar(111))
 ,cast('1000001' as varchar(107))
from (sel 1 one) i145    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Like' as varchar(105))
 ,cast('OSH%' as varchar(131))
 ,cast('IBM Data Stage' as varchar(129))
 ,cast('ETL' as varchar(111))
 ,cast('1000002' as varchar(107))
from (sel 1 one) i146    ;
# Out:
# Success: 0 rows affected
# Success: 147 rows affected

# %%
create volatile table dim_app as
(
  select
   o.AppID
  ,coalesce(p.App_Bucket,'Unknown') as App_Bucket
  ,coalesce(p.Use_Bucket,'Unknown')  as Use_Bucket
  ,coalesce(p.Priority,1e6) as Priority_
  ,coalesce(p.Pattern_Type,'Equal')  as Pattern_Type
  ,coalesce(p.Pattern, o.AppID)      as Pattern
  ,coalesce(p.SiteID, 'None')        as SiteID_
  from (select distinct AppID from pdcrinfo.DBQLogTbl_Hst
        where LogDate between Current_Date - 8 and Current_Date - 1
        union
        select distinct AppID from pdcrinfo.DBQLSummaryTbl_Hst
        where LogDate between Current_Date - 8 and Current_Date - 1
        ) as o
  left join "dim_app.csv" as p
    on (case
        when p.Pattern_Type = 'Equal' and lower(o.AppID) = lower(p.Pattern) then 1
        when p.Pattern_Type = 'Like'  and lower(o.AppID) like lower(p.Pattern) then 1
        when p.Pattern_Type = 'RegEx'
         and character_length(regexp_substr(o.AppID, p.Pattern,1,1,'i'))>0 then 1
        else 0 end) = 1
  qualify Priority_ = min(Priority_)over(partition by o.AppID)
  where (lower(SiteID_) in('default','none') or lower('TRANSCEND02') like lower(SiteID_))
) with data
no primary index
on commit preserve rows
;
# Out:
# Success: 0 rows affected

# %%
Select top 5 * from dim_app
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory348342"><style>
#       table.tdhistory348342 { display: block !important; min-height: 189px !important; overflow: auto !important; height: 189px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory348342 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory348342:last-child { text-align: left !important; }
#       tbody.tdhistory348342 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
# ...

# %% [markdown]
# <br><br><br>
# ## <u>Dim_TDInternal_Databases</u>
# List of databases considered to be "internal" and so counted differently
# ### ToDo:
# - asdf

# %%
CREATE MULTISET VOLATILE TABLE "dim_tdinternal_databases.csv"
("SiteID"                      VARCHAR(107)  CHARACTER SET UNICODE 
,"dbname"                      VARCHAR(115)  CHARACTER SET UNICODE 
) NO PRIMARY INDEX
ON COMMIT PRESERVE ROWS;
# Out:
# Success: 0 rows affected

# %%
INSERT INTO "dim_tdinternal_databases.csv"
SELECT
  cast('Default' as varchar(107))
 ,cast('All' as varchar(115))
from (sel 1 one) i0    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('ARCUSERS' as varchar(115))
from (sel 1 one) i1    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('console' as varchar(115))
from (sel 1 one) i2    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Crashdumps' as varchar(115))
from (sel 1 one) i3    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('dbadip' as varchar(115))
from (sel 1 one) i4    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('dbadmin' as varchar(115))
from (sel 1 one) i5    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('DBC' as varchar(115))
from (sel 1 one) i6    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('DBCMANAGER' as varchar(115))
from (sel 1 one) i7    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('dbcmngr' as varchar(115))
from (sel 1 one) i8    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('dbcpurge' as varchar(115))
from (sel 1 one) i9    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Default' as varchar(115))
from (sel 1 one) i10    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('DLADMIN' as varchar(115))
from (sel 1 one) i11    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('External_AP' as varchar(115))
from (sel 1 one) i12    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('GTMOPS' as varchar(115))
from (sel 1 one) i13    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('LockLogShredder' as varchar(115))
from (sel 1 one) i14    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('PDCRAccess' as varchar(115))
from (sel 1 one) i15    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('PDCRADM' as varchar(115))
from (sel 1 one) i16    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('PDCRAdmin' as varchar(115))
from (sel 1 one) i17    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('PDCRDATA' as varchar(115))
from (sel 1 one) i18    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('PDCRHIGA' as varchar(115))
from (sel 1 one) i19    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('PDCRINFO' as varchar(115))
from (sel 1 one) i20    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('PDCRSTG' as varchar(115))
from (sel 1 one) i21    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('PDCRTPCD' as varchar(115))
from (sel 1 one) i22    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('PUBLIC' as varchar(115))
from (sel 1 one) i23    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('SECADMIN' as varchar(115))
from (sel 1 one) i24    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('SPOOL_RESERVE' as varchar(115))
from (sel 1 one) i25    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('SQLJ' as varchar(115))
from (sel 1 one) i26    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Sys_Calendar' as varchar(115))
from (sel 1 one) i27    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('SysAdmin' as varchar(115))
from (sel 1 one) i28    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('SYSBACK' as varchar(115))
from (sel 1 one) i29    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('SYSBAR' as varchar(115))
from (sel 1 one) i30    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('SYSDBA' as varchar(115))
from (sel 1 one) i31    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('SYSJDBC' as varchar(115))
from (sel 1 one) i32    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('SYSLIB' as varchar(115))
from (sel 1 one) i33    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('SYSSPATIAL' as varchar(115))
from (sel 1 one) i34    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('SystemFe' as varchar(115))
from (sel 1 one) i35    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('SYSUDTLIB' as varchar(115))
from (sel 1 one) i36    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('SYSUIF' as varchar(115))
from (sel 1 one) i37    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('SYSXML' as varchar(115))
from (sel 1 one) i38    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('TACADMIN' as varchar(115))
from (sel 1 one) i39    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('TD_COD' as varchar(115))
from (sel 1 one) i40    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('td_ffe_svc_acct' as varchar(115))
from (sel 1 one) i41    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('TD_RECONFIG' as varchar(115))
from (sel 1 one) i42    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('TD_SERVER_DB' as varchar(115))
from (sel 1 one) i43    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('TD_SYSFNLIB' as varchar(115))
from (sel 1 one) i44    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('TD_SYSGPL' as varchar(115))
from (sel 1 one) i45    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('TD_SYSXML' as varchar(115))
from (sel 1 one) i46    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('TDAP_Admin' as varchar(115))
from (sel 1 one) i47    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('TDMaps' as varchar(115))
from (sel 1 one) i48    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('TDPUSER' as varchar(115))
from (sel 1 one) i49    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('TDQCD' as varchar(115))
from (sel 1 one) i50    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('TDStats' as varchar(115))
from (sel 1 one) i51    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('tdwm' as varchar(115))
from (sel 1 one) i52    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('USERSPACE' as varchar(115))
from (sel 1 one) i53    UNION ALL
SELECT
  cast('Default' as varchar(107))
 ,cast('Viewpoint' as varchar(115))
from (sel 1 one) i54    ;
# Out:
# Success: 55 rows affected

# %%
Select top 5 * from "dim_tdinternal_databases.csv"
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory397766"><style>
#       table.tdhistory397766 { display: block !important; min-height: 189px !important; overflow: auto !important; height: 189px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory397766 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory397766:last-child { text-align: left !important; }
#       tbody.tdhistory397766 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
# ...

# %% [markdown]
# <br><br><br>
# ## <u>Dim_User</u>
# Requires "dim_tdinternal_databases.csv" to be loaded
# ### ToDo:
# - asdf

# %%
drop table active_users
# Out:
# Success: 0 rows affected

# %%
CREATE SET VOLATILE TABLE  active_users as 
(
 Select 
  Active_UserName
 ,sum(Query_Cnt) as Query_Cnt
 ,avg(Query_Complexity_Score) as Query_Complexity_Score
 ,sum(CPU_Sec) as CPU_Sec
 ,sum(IOGB) as IOGB
 ,sum(Runtime_Sec) as Runtime_Sec
 ,sum(Error_Cnt) as Error_Cnt
 from (
        select UserName as Active_UserName
        ,zeroifnull(sum(cast(Statements as BigInt))) as Query_Cnt
        ,zeroifnull(avg(cast(NumSteps as Int))) as Query_Complexity_Score
        ,zeroifnull(sum(cast(ParserCPUTime+AMPCPUTime as Decimal(18,2)))) as CPU_Sec
        ,zeroifnull(cast(sum(ReqIOKB(BigInt))/1e6 as Decimal(18,0))) as IOGB
        ,zeroifnull(sum(cast(TotalFirstRespTime as Decimal(18,6)))) as Runtime_Sec
        ,zeroifnull(sum(cast((case when ErrorCode not in(0,3158) then 1 else 0 end) as decimal(9,0)))) as Error_Cnt
        from pdcrinfo.dbqLogTbl_Hst 
        where LogDate = DATE-2 
        group by 1
            union 
        select UserName as Active_UserName
        ,zeroifnull(sum(cast(QueryCount as BigInt))) as Query_Cnt
        ,null as Query_Complexity_Score
        ,zeroifnull(sum(cast(ParserCPUTime+AMPCPUTime as Decimal(18,2)))) as CPU_Sec
        ,zeroifnull(cast(sum(ReqPhysIOKB(BigInt))/1e6 as Decimal(18,2))) as IOGB
        ,0 as Runtime_Sec
        ,0 as Error_Cnt
        from pdcrinfo.dbqlSummaryTbl_Hst 
        where LogDate = DATE-2 
        group by 1
      ) as au
 group by au.Active_UserName
) 
with data 
primary index(Active_UserName)
on commit preserve rows
;
# Out:
# Success: 0 rows affected

# %%
CREATE MULTISET VOLATILE TABLE "dim_user.csv"
("SiteID"                      VARCHAR(110)  CHARACTER SET UNICODE 
,"Pattern_Type"                VARCHAR(105)  CHARACTER SET UNICODE 
,"Pattern"                     VARCHAR(116)  CHARACTER SET UNICODE 
,"User_Bucket"                 VARCHAR(112)  CHARACTER SET UNICODE 
,"User_Department"             VARCHAR(105)  CHARACTER SET UNICODE 
,"User_SubDepartment"          VARCHAR(105)  CHARACTER SET UNICODE 
,"User_Region"                 VARCHAR(104)  CHARACTER SET UNICODE 
,"Priority"                    VARCHAR(107)  CHARACTER SET UNICODE 
) NO PRIMARY INDEX
ON COMMIT PRESERVE ROWS;
# Out:
# Unable to run SQL: Unable to run SQL query: Database reported error:3803:Table 'dim_user.csv' already exists.

# %%
delete from "dim_user.csv" all;
INSERT INTO "dim_user.csv"
SELECT
  cast('Default' as varchar(110))
 ,cast('Like' as varchar(105))
 ,cast('%STG%USER%' as varchar(116))
 ,cast('ETL' as varchar(112))
 ,cast('IT' as varchar(105))
 ,cast('Stage' as varchar(105))
 ,cast('None' as varchar(104))
 ,cast('5000' as varchar(107))
from (sel 1 one) i0    UNION ALL
SELECT
  cast('Default' as varchar(110))
 ,cast('Like' as varchar(105))
 ,cast('%ETL%' as varchar(116))
 ,cast('ETL' as varchar(112))
 ,cast('IT' as varchar(105))
 ,cast('ETL' as varchar(105))
 ,cast('None' as varchar(104))
 ,cast('5100' as varchar(107))
from (sel 1 one) i1    UNION ALL
SELECT
  cast('Default' as varchar(110))
 ,cast('Like' as varchar(105))
 ,cast('BAR_%' as varchar(116))
 ,cast('Admin' as varchar(112))
 ,cast('IT' as varchar(105))
 ,cast('DBA' as varchar(105))
 ,cast('None' as varchar(104))
 ,cast('5200' as varchar(107))
from (sel 1 one) i2    UNION ALL
SELECT
  cast('Default' as varchar(110))
 ,cast('Like' as varchar(105))
 ,cast('%_BAR' as varchar(116))
 ,cast('Admin' as varchar(112))
 ,cast('IT' as varchar(105))
 ,cast('DBA' as varchar(105))
 ,cast('None' as varchar(104))
 ,cast('5300' as varchar(107))
from (sel 1 one) i3    UNION ALL
SELECT
  cast('Default' as varchar(110))
 ,cast('Like' as varchar(105))
 ,cast('DSA_%' as varchar(116))
 ,cast('Admin' as varchar(112))
 ,cast('IT' as varchar(105))
 ,cast('DBA' as varchar(105))
 ,cast('None' as varchar(104))
 ,cast('5400' as varchar(107))
from (sel 1 one) i4    UNION ALL
SELECT
  cast('Default' as varchar(110))
 ,cast('Like' as varchar(105))
 ,cast('%_DSA' as varchar(116))
 ,cast('Admin' as varchar(112))
 ,cast('IT' as varchar(105))
 ,cast('DBA' as varchar(105))
 ,cast('None' as varchar(104))
 ,cast('5500' as varchar(107))
from (sel 1 one) i5    UNION ALL
SELECT
  cast('Default' as varchar(110))
 ,cast('Like' as varchar(105))
 ,cast('ARC_%' as varchar(116))
 ,cast('Admin' as varchar(112))
 ,cast('IT' as varchar(105))
 ,cast('DBA' as varchar(105))
 ,cast('None' as varchar(104))
 ,cast('5600' as varchar(107))
from (sel 1 one) i6    UNION ALL
SELECT
  cast('Default' as varchar(110))
 ,cast('Like' as varchar(105))
 ,cast('%_ARC' as varchar(116))
 ,cast('Admin' as varchar(112))
 ,cast('IT' as varchar(105))
 ,cast('DBA' as varchar(105))
 ,cast('None' as varchar(104))
 ,cast('5700' as varchar(107))
from (sel 1 one) i7    UNION ALL
SELECT
  cast('Default' as varchar(110))
 ,cast('Like' as varchar(105))
 ,cast('DBADMIN%' as varchar(116))
 ,cast('Admin' as varchar(112))
 ,cast('IT' as varchar(105))
 ,cast('DBA' as varchar(105))
 ,cast('None' as varchar(104))
 ,cast('5800' as varchar(107))
from (sel 1 one) i8    UNION ALL
SELECT
  cast('Default' as varchar(110))
 ,cast('Like' as varchar(105))
 ,cast('%_ADMIN' as varchar(116))
 ,cast('Admin' as varchar(112))
 ,cast('IT' as varchar(105))
 ,cast('DBA' as varchar(105))
 ,cast('None' as varchar(104))
 ,cast('5900' as varchar(107))
from (sel 1 one) i9    UNION ALL
SELECT
  cast('Default' as varchar(110))
 ,cast('Like' as varchar(105))
 ,cast('%_DBA' as varchar(116))
 ,cast('Admin' as varchar(112))
 ,cast('IT' as varchar(105))
 ,cast('DBA' as varchar(105))
 ,cast('None' as varchar(104))
 ,cast('6000' as varchar(107))
from (sel 1 one) i10    UNION ALL
SELECT
  cast('TRANSCEND%' as varchar(110))
 ,cast('Regex' as varchar(105))
 ,cast('[a-z]{2}[0-9]{6}' as varchar(116))
 ,cast('Quicklook ID' as varchar(112))
 ,cast('TDOrg' as varchar(105))
 ,cast('Other' as varchar(105))
 ,cast('None' as varchar(104))
 ,cast('1000000' as varchar(107))
from (sel 1 one) i11    UNION ALL
SELECT
  cast('TRNAWS%' as varchar(110))
 ,cast('Regex' as varchar(105))
 ,cast('[a-z]{2}[0-9]{6}' as varchar(116))
 ,cast('Quicklook ID' as varchar(112))
 ,cast('TDOrg' as varchar(105))
 ,cast('Other' as varchar(105))
 ,cast('None' as varchar(104))
 ,cast('1000000' as varchar(107))
from (sel 1 one) i12    ;
# Out:
# Success: 136 rows affected
# Success: 13 rows affected

# %%
insert into "dim_user.csv"
  select
   SiteID       as Site_ID
  ,'Equal'      as Pattern_Type
  ,trim(dbname) as Pattern
  ,'TDInternal' as User_Bucket
  ,'TDInternal' as User_Department
  ,'TDInternal' as User_SubDepartment
  ,'TDInternal' as User_Region
  ,1            as Priority
from "dim_tdinternal_databases.csv" idb
;
# Out:
# Success: 55 rows affected

# %%
drop table dim_user
# Out:
# Success: 0 rows affected

# %%
create volatile table dim_user as
(
  select
   o.UserName
  ,o.UserHash
  ,o.Active_Flag
  ,coalesce(p.User_Bucket,'Unknown') as User_Bucket
  ,coalesce(p.User_Department, 'Unknown') as User_Department
  ,coalesce(p.User_SubDepartment, 'Unknown') as User_SubDepartment
  ,coalesce(p.User_Region, 'Unknown') as User_Region
  ,coalesce(p.Priority,1e6)(int) as Priority_
  ,coalesce(p.Pattern_Type,'Equal')  as Pattern_Type
  ,coalesce(p.Pattern, o.UserName) as Pattern
  ,coalesce(p.SiteID, 'None')        as SiteID_
  ,Query_Cnt
  ,Query_Complexity_Score
  ,CPU_Sec
  ,IOGB
  ,Runtime_Sec
  ,Error_Cnt
  from (select
         trim(DatabaseName) as UserName
        ,case when Active_UserName is null then 0 else 1 end (ByteInt) as Active_Flag
        ,Query_Cnt
        ,Query_Complexity_Score
        ,CPU_Sec
        ,IOGB
        ,Runtime_Sec
        ,Error_Cnt
        ,substr(Username,1,3) as first3
        ,substr(Username,floor(character_length(Username)/2)-1,3) as middle3
        ,substr(Username,character_length(Username)-3,3) as last3
        /* generate UserHash value */
        ,trim(cast(from_bytes(hashrow( Username),'base16') as char(9))) ||
         trim(cast(from_bytes(hashrow( first3  ),'base16') as char(9))) ||
         trim(cast(from_bytes(hashrow( middle3 ),'base16') as char(9))) ||
         trim(cast(from_bytes(hashrow( last3   ),'base16') as char(9))) as UserHash
        from dbc.DatabasesV as dv
        left outer join
             (
                 /* determine active users (during timeframe) and their impact */
                 Select
                  Active_UserName
                 ,sum(Query_Cnt) as Query_Cnt
                 ,avg(Query_Complexity_Score) as Query_Complexity_Score
                 ,sum(CPU_Sec) as CPU_Sec
                 ,sum(IOGB) as IOGB
                 ,sum(Runtime_Sec) as Runtime_Sec
                 ,sum(Error_Cnt) as Error_Cnt
                 from (
                        select UserName as Active_UserName
                        ,zeroifnull(sum(cast(Statements as BigInt))) as Query_Cnt
                        ,zeroifnull(avg(cast(NumSteps as Int))) as Query_Complexity_Score
                        ,zeroifnull(sum(cast(ParserCPUTime+AMPCPUTime as Decimal(18,2)))) as CPU_Sec
                        ,zeroifnull(cast(sum(ReqIOKB(BigInt))/1e6 as Decimal(18,3))) as IOGB
                        ,zeroifnull(sum(cast(TotalFirstRespTime as Decimal(18,6)))) as Runtime_Sec
                        ,zeroifnull(sum(cast((case when ErrorCode not in(0,3158) then 1 else 0 end) as decimal(9,0)))) as Error_Cnt
                        from dbc.QryLogV
                        where cast(starttime as DATE) = DATE
                        group by 1
                            union
                        select UserName as Active_UserName
                        ,zeroifnull(sum(cast(QueryCount as BigInt))) as Query_Cnt
                        ,null as Query_Complexity_Score
                        ,zeroifnull(sum(cast(ParserCPUTime+AMPCPUTime as Decimal(18,2)))) as CPU_Sec
                        ,zeroifnull(cast(sum(ReqPhysIOKB(BigInt))/1e6 as Decimal(18,3))) as IOGB
                        ,0 as Runtime_Sec
                        ,0 as Error_Cnt
                        from dbc.QryLogSummaryV
                        where cast(starttime as DATE) = DATE
                        group by 1
                      ) as au1
                 group by Active_UserName
             ) as au2
          on DatabaseName = Active_UserName
        where DBKind = 'U'
        ) as o
  left join "dim_user.csv" as p
    on (case
        when p.Pattern_Type = 'Equal' and lower(o.UserName) = lower(p.Pattern) then 1
        when p.Pattern_Type = 'Like'  and lower(o.UserName) like lower(p.Pattern) then 1
        when p.Pattern_Type = 'RegEx'
         and character_length(regexp_substr(o.UserName, p.Pattern,1,1,'i'))>0 then 1
        else 0 end) = 1
    and (lower(SiteID_) in('default','none') or lower('TRANSCEND02') like lower(SiteID_))
  qualify Priority_ = min(Priority_)over(partition by o.UserName)
) with data
primary index (UserName)
on commit preserve rows
;
# Out:
# Success: 0 rows affected

# %%
Select top 100 * from dim_user
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory569804"><style>
#       table.tdhistory569804 { display: block !important; min-height: 588px !important; overflow: auto !important; height: 588px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory569804 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory569804:last-child { text-align: left !important; }
#       tbody.tdhistory569804 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
# ...

# %%
drop table dim_user
# Out:
# Success: 0 rows affected

# %% [markdown]
# <br><br><br>
# ## <u>Dim_Statement</u>
# ### ToDo:
# - asdf

# %%
        select
         trim(DatabaseName) as UserName
        ,case when Active_UserName is null then 0 else 1 end (ByteInt) as Active_Flag
        ,substr(Username,1,3) as first3
        ,substr(Username,floor(character_length(Username)/2)-1,3) as middle3
        ,substr(Username,character_length(Username)-3,3) as last3
        /* generate UserHash value */
        ,trim(cast(from_bytes(hashrow( Username),'base16') as char(9))) ||
         trim(cast(from_bytes(hashrow( first3  ),'base16') as char(9))) ||
         trim(cast(from_bytes(hashrow( middle3 ),'base16') as char(9))) ||
         trim(cast(from_bytes(hashrow( last3   ),'base16') as char(9))) as UserHash
        from dbc.DatabasesV as dv 
        left outer join active_users as au
          on DatabaseName = Active_UserName
        where DBKind = 'U'
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory710067"><style>
#       table.tdhistory710067 { display: block !important; min-height: 588px !important; overflow: auto !important; height: 588px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory710067 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory710067:last-child { text-align: left !important; }
#       tbody.tdhistory710067 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
# ...

# %%
select * from dbc.columns
where databasename = 'pdcrinfo'
and tablename = 'dbqlSummaryTbl_Hst'
order by ColumnID
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory897441"><style>
#       table.tdhistory897441 { display: block !important; min-height: 588px !important; overflow: auto !important; height: 588px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory897441 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory897441:last-child { text-align: left !important; }
#       tbody.tdhistory897441 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
# ...
